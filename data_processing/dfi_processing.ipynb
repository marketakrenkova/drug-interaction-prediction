# %%
import pandas as pd
import itertools

# %%
triplets_dir = '../data/triplets/'

# %%
dfi = pd.read_csv(triplets_dir + 'dfi.tsv', sep='\t', index_col=[0])
dfi
# Out:
#         drug1                       interaction
# 0     DB00001  increase_antiplatelet_activities  \
# 1     DB00006            decrease_effectiveness
# 2     DB00006  increase_antiplatelet_activities
# 3     DB00008          decrease_adverse_effects
# 4     DB00009  increase_antiplatelet_activities
# ...       ...                               ...
# 1506  DB15982            increase_effectiveness
# 1507  DB16165            decrease_effectiveness
# 1508  DB16261            increase_effectiveness
# 1509  DB16390            decrease_effectiveness
# 1510  DB16703            increase_effectiveness
#
#                                                   drug2
# 0     herbs and supplements with anticoagulant/antip...
# 1                                             echinacea
# 2     herbs and supplements with anticoagulant/antip...
# 3                                                 water
# 4     herbs and supplements with anticoagulant/antip...
# ...                                                 ...
# 1506                                               food
# 1507                                         grapefruit
# 1508                                    a high fat meal
# 1509                                    St. John's Wort
# 1510                                               food
#
# [1511 rows x 3 columns]

# %%
# Herbs with antiplatelet properties
# https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6459456/

herbs = ['aloe', 'cranberry', 'chamomile', 'feverfew', 'garlic', 'ginger', 'ginkgo', 
         'meadowsweet', 'turmeric', 'white willow', 'fenugreek', 'red clover', 'dong quai', 
        'evening primrose', 'ginseng', 'flaxseed', 'grapefruit', 'green tea', 'oregano', 'saw palmetto']

# %%
# histamine-containing foods
# https://www.healthline.com/health/histamine-intolerance#diet

histamine_food =['alcohol', 'yoghurt', 'fermented food', 'avocado', 'eggplant', 'spinach', 'shellfish']

# %%
# tyramine-containing foods and supplements 
# https://www.webmd.com/diet/foods-high-in-tyramine

tyramine_food = ['cheese', 'feremnted food', 'orange', 'grapefruit', 'lemon', 'lime', 'tangerine',
                'banana', 'pineapple', 'avocado', 'alcohol']

# %%
food_name_map = pd.read_csv(triplets_dir + 'food_name.tsv', sep='\t', index_col =[0])
food_ids = food_name_map.public_id
food_names = food_name_map.name.str.lower()
food_id_map_dict = dict(zip(food_names, food_ids))
food_id_map_dict
# Out:
# {'angelica': 'FOOD00001',
#  'savoy cabbage': 'FOOD00002',
#  'silver linden': 'FOOD00003',
#  'kiwi': 'FOOD00004',
#  'allium': 'FOOD00005',
#  'garden onion': 'FOOD00006',
#  'leek': 'FOOD00007',
#  'garlic': 'FOOD00008',
#  'chives': 'FOOD00009',
#  'lemon verbena': 'FOOD00010',
#  'cashew nut': 'FOOD00011',
#  'pineapple': 'FOOD00012',
#  'dill': 'FOOD00013',
#  'custard apple': 'FOOD00014',
#  'wild celery': 'FOOD00015',
#  'peanut': 'FOOD00016',
#  'burdock': 'FOOD00017',
#  'horseradish': 'FOOD00018',
#  'tarragon': 'FOOD00019',
#  'mugwort': 'FOOD00020',
#  'asparagus': 'FOOD00021',
#  'oat': 'FOOD00022',
#  'star fruit': 'FOOD00023',
#  'brazil nut': 'FOOD00024',
#  'common beet': 'FOOD00025',
#  'borage': 'FOOD00026',
#  'chinese mustard': 'FOOD00027',
#  'swede': 'FOOD00028',
#  'rape': 'FOOD00029',
#  'common cabbage': 'FOOD00030',
#  'cauliflower': 'FOOD00031',
#  'brussel sprouts': 'FOOD00032',
#  'kohlrabi': 'FOOD00033',
#  'broccoli': 'FOOD00034',
#  'chinese cabbage': 'FOOD00035',
#  'turnip': 'FOOD00036',
#  'pigeon pea': 'FOOD00037',
#  'tea': 'FOOD00038',
#  'capers': 'FOOD00039',
#  'pepper': 'FOOD00040',
#  'papaya': 'FOOD00041',
#  'safflower': 'FOOD00042',
#  'caraway': 'FOOD00043',
#  'pecan nut': 'FOOD00044',
#  'chestnut': 'FOOD00045',
#  'roman camomile': 'FOOD00046',
#  'chickpea': 'FOOD00047',
#  'endive': 'FOOD00048',
#  'chicory': 'FOOD00049',
#  'chinese cinnamon': 'FOOD00050',
#  'ceylon cinnamon': 'FOOD00051',
#  'watermelon': 'FOOD00052',
#  'lime': 'FOOD00053',
#  'lemon': 'FOOD00054',
#  'pummelo': 'FOOD00055',
#  'mandarin orange (clementine, tangerine)': 'FOOD00056',
#  'sweet orange': 'FOOD00057',
#  'coffee': 'FOOD00058',
#  'arabica coffee': 'FOOD00059',
#  'robusta coffee': 'FOOD00060',
#  'coriander': 'FOOD00061',
#  'common hazelnut': 'FOOD00062',
#  'saffron': 'FOOD00063',
#  'muskmelon': 'FOOD00064',
#  'cucumber': 'FOOD00065',
#  'cucurbita': 'FOOD00066',
#  'cumin': 'FOOD00067',
#  'turmeric': 'FOOD00068',
#  'quince': 'FOOD00069',
#  'lemon grass': 'FOOD00070',
#  'globe artichoke': 'FOOD00071',
#  'wild carrot': 'FOOD00072',
#  'japanese persimmon': 'FOOD00073',
#  'cardamom': 'FOOD00074',
#  'black crowberry': 'FOOD00075',
#  'loquat': 'FOOD00076',
#  'rocket salad (ssp.)': 'FOOD00077',
#  'wax apple': 'FOOD00078',
#  'common buckwheat': 'FOOD00079',
#  'tartary buckwheat': 'FOOD00080',
#  'fig': 'FOOD00081',
#  'fennel': 'FOOD00082',
#  'strawberry': 'FOOD00083',
#  'black huckleberry': 'FOOD00084',
#  'soy bean': 'FOOD00085',
#  'sunflower': 'FOOD00086',
#  'sea-buckthornberry': 'FOOD00087',
#  'barley': 'FOOD00088',
#  'hyssop': 'FOOD00089',
#  'star anise': 'FOOD00090',
#  'swamp cabbage': 'FOOD00091',
#  'sweet potato': 'FOOD00092',
#  'black walnut': 'FOOD00093',
#  'common walnut': 'FOOD00094',
#  'lettuce': 'FOOD00095',
#  'grass pea': 'FOOD00096',
#  'sweet bay': 'FOOD00097',
#  'lentils': 'FOOD00098',
#  'garden cress': 'FOOD00099',
#  'lovage': 'FOOD00100',
#  'flaxseed': 'FOOD00101',
#  'mexican oregano': 'FOOD00102',
#  'lichee': 'FOOD00103',
#  'lupine': 'FOOD00104',
#  'apple': 'FOOD00105',
#  'mango': 'FOOD00106',
#  'german camomile': 'FOOD00107',
#  'lemon balm': 'FOOD00108',
#  'mentha': 'FOOD00109',
#  'orange mint': 'FOOD00110',
#  'cornmint': 'FOOD00111',
#  'spearmint': 'FOOD00112',
#  'peppermint': 'FOOD00113',
#  'medlar': 'FOOD00114',
#  'bitter gourd': 'FOOD00115',
#  'mulberry': 'FOOD00116',
#  'black mulberry': 'FOOD00117',
#  'nutmeg': 'FOOD00118',
#  'sweet basil': 'FOOD00119',
#  'evening primrose': 'FOOD00120',
#  'olive': 'FOOD00121',
#  'sweet marjoram': 'FOOD00122',
#  'pot marjoram': 'FOOD00123',
#  'common oregano': 'FOOD00124',
#  'rice': 'FOOD00125',
#  'millet': 'FOOD00126',
#  'poppy': 'FOOD00127',
#  'passion fruit': 'FOOD00128',
#  'parsnip': 'FOOD00129',
#  'avocado': 'FOOD00130',
#  'parsley': 'FOOD00131',
#  'scarlet bean': 'FOOD00132',
#  'lima bean': 'FOOD00133',
#  'common bean': 'FOOD00134',
#  'date': 'FOOD00135',
#  'black chokeberry': 'FOOD00136',
#  'anise': 'FOOD00137',
#  'pine nut': 'FOOD00138',
#  'pepper (spice)': 'FOOD00139',
#  'pistachio': 'FOOD00140',
#  'common pea': 'FOOD00141',
#  'purslane': 'FOOD00142',
#  'prunus (cherry, plum)': 'FOOD00143',
#  'apricot': 'FOOD00144',
#  'sweet cherry': 'FOOD00145',
#  'sour cherry': 'FOOD00146',
#  'european plum': 'FOOD00147',
#  'almond': 'FOOD00148',
#  'peach': 'FOOD00149',
#  'guava': 'FOOD00150',
#  'pomegranate': 'FOOD00151',
#  'pear': 'FOOD00152',
#  'radish': 'FOOD00153',
#  'garden rhubarb': 'FOOD00154',
#  'blackcurrant': 'FOOD00155',
#  'redcurrant': 'FOOD00156',
#  'gooseberry': 'FOOD00157',
#  'watercress': 'FOOD00158',
#  'rosemary': 'FOOD00159',
#  'rubus (blackberry, raspberry)': 'FOOD00160',
#  'cloudberry': 'FOOD00161',
#  'red raspberry': 'FOOD00162',
#  'black raspberry': 'FOOD00163',
#  'sorrel': 'FOOD00164',
#  'common sage': 'FOOD00165',
#  'black elderberry': 'FOOD00166',
#  'summer savory': 'FOOD00167',
#  'winter savory': 'FOOD00168',
#  'rye': 'FOOD00169',
#  'sesame': 'FOOD00170',
#  'garden tomato': 'FOOD00171',
#  'cherry tomato': 'FOOD00172',
#  'garden tomato (var.)': 'FOOD00173',
#  'eggplant': 'FOOD00174',
#  'potato': 'FOOD00175',
#  'rowanberry': 'FOOD00176',
#  'sorghum': 'FOOD00177',
#  'spinach': 'FOOD00178',
#  'cloves': 'FOOD00179',
#  'tamarind': 'FOOD00180',
#  'dandelion': 'FOOD00181',
#  'cocoa bean': 'FOOD00182',
#  'common thyme': 'FOOD00183',
#  'linden': 'FOOD00184',
#  'small-leaf linden': 'FOOD00185',
#  'fenugreek': 'FOOD00186',
#  'common wheat': 'FOOD00187',
#  'vaccinium (blueberry, cranberry, huckleberry)': 'FOOD00188',
#  'lowbush blueberry': 'FOOD00189',
#  'sparkleberry': 'FOOD00190',
#  'highbush blueberry': 'FOOD00191',
#  'american cranberry': 'FOOD00192',
#  'bilberry': 'FOOD00193',
#  'lingonberry': 'FOOD00194',
#  'vanilla': 'FOOD00195',
#  'common verbena': 'FOOD00196',
#  'broad bean': 'FOOD00197',
#  'adzuki bean': 'FOOD00198',
#  'gram bean': 'FOOD00199',
#  'mung bean': 'FOOD00200',
#  'climbing bean': 'FOOD00201',
#  'cowpea': 'FOOD00202',
#  'muscadine grape': 'FOOD00203',
#  'common grape': 'FOOD00204',
#  'corn': 'FOOD00205',
#  'ginger': 'FOOD00206',
#  'arctic blackberry': 'FOOD00207',
#  'banana': 'FOOD00208',
#  'bayberry': 'FOOD00209',
#  "elliott's blueberry": 'FOOD00210',
#  'canada blueberry': 'FOOD00211',
#  'bog bilberry': 'FOOD00212',
#  'buffalo currant': 'FOOD00213',
#  'celeriac': 'FOOD00214',
#  'celery stalks': 'FOOD00215',
#  'chinese chives': 'FOOD00216',
#  'european cranberry': 'FOOD00217',
#  'deerberry': 'FOOD00218',
#  'ginseng': 'FOOD00219',
#  'cascade huckleberry': 'FOOD00220',
#  'oval-leaf huckleberry': 'FOOD00221',
#  'evergreen huckleberry': 'FOOD00222',
#  'red huckleberry': 'FOOD00223',
#  'longan': 'FOOD00224',
#  'macadamia nut (m. tetraphylla)': 'FOOD00225',
#  'garden onion (var.)': 'FOOD00226',
#  'summer grape': 'FOOD00227',
#  'fox grape': 'FOOD00228',
#  'nectarine': 'FOOD00229',
#  'peach (var.)': 'FOOD00230',
#  'pepper (c. baccatum)': 'FOOD00231',
#  'pepper (c. chinense)': 'FOOD00232',
#  'pepper (capsicum)': 'FOOD00233',
#  'rambutan': 'FOOD00234',
#  'red rice': 'FOOD00235',
#  'annual wild rice': 'FOOD00236',
#  'swiss chard': 'FOOD00237',
#  'lemon thyme': 'FOOD00238',
#  'tronchuda cabbage': 'FOOD00239',
#  'japanese walnut': 'FOOD00240',
#  'welsh onion': 'FOOD00241',
#  'hard wheat': 'FOOD00242',
#  'shallot': 'FOOD00243',
#  'rocket salad': 'FOOD00244',
#  'carrot': 'FOOD00245',
#  'triticale': 'FOOD00246',
#  'black cabbage': 'FOOD00247',
#  'half-highbush blueberry': 'FOOD00248',
#  'celery leaves': 'FOOD00249',
#  'chicory leaves': 'FOOD00250',
#  'komatsuna': 'FOOD00251',
#  'pak choy': 'FOOD00252',
#  'napa cabbage': 'FOOD00253',
#  'chicory roots': 'FOOD00254',
#  'grapefruit/pummelo hybrid': 'FOOD00255',
#  'grapefruit': 'FOOD00256',
#  'jostaberry': 'FOOD00257',
#  'kai-lan': 'FOOD00258',
#  'italian oregano': 'FOOD00259',
#  'oxheart cabbage': 'FOOD00260',
#  'daikon radish': 'FOOD00261',
#  'black radish': 'FOOD00262',
#  'radish (var.)': 'FOOD00263',
#  'red beetroot': 'FOOD00264',
#  'sweet rowanberry': 'FOOD00265',
#  'pineappple sage': 'FOOD00266',
#  'skunk currant': 'FOOD00267',
#  'beer': 'FOOD00268',
#  'other bread': 'FOOD00269',
#  'breakfast cereal': 'FOOD00270',
#  'other soy product': 'FOOD00271',
#  'other cereal product': 'FOOD00272',
#  'pasta': 'FOOD00273',
#  'biscuit': 'FOOD00274',
#  'sourdough': 'FOOD00275',
#  'spirit': 'FOOD00276',
#  'fortified wine': 'FOOD00277',
#  'other alcoholic beverage': 'FOOD00278',
#  'abalone': 'FOOD00279',
#  'abiyuch': 'FOOD00280',
#  'acerola': 'FOOD00281',
#  'acorn': 'FOOD00282',
#  'winter squash': 'FOOD00283',
#  'agar': 'FOOD00284',
#  'red king crab': 'FOOD00285',
#  'alfalfa': 'FOOD00286',
#  'allspice': 'FOOD00287',
#  'amaranth': 'FOOD00288',
#  'arrowhead': 'FOOD00289',
#  'arrowroot': 'FOOD00290',
#  'asian pear': 'FOOD00291',
#  'atlantic herring': 'FOOD00292',
#  'atlantic mackerel': 'FOOD00293',
#  'painted comber': 'FOOD00294',
#  'atlantic pollock': 'FOOD00295',
#  'atlantic wolffish': 'FOOD00296',
#  'bamboo shoots': 'FOOD00297',
#  'striped bass': 'FOOD00298',
#  'beech nut': 'FOOD00299',
#  'beluga whale': 'FOOD00300',
#  'bison': 'FOOD00301',
#  'alaska blackfish': 'FOOD00302',
#  'blue crab': 'FOOD00303',
#  'blue mussel': 'FOOD00304',
#  'northern bluefin tuna': 'FOOD00305',
#  'bluefish': 'FOOD00306',
#  'wild boar': 'FOOD00307',
#  'bowhead whale': 'FOOD00308',
#  'breadfruit': 'FOOD00309',
#  'breadnut tree seed': 'FOOD00310',
#  'rapini': 'FOOD00311',
#  'buffalo': 'FOOD00312',
#  'burbot': 'FOOD00313',
#  'giant butterbur': 'FOOD00314',
#  'american butterfish': 'FOOD00315',
#  'butternut': 'FOOD00316',
#  'butternut squash': 'FOOD00317',
#  'calabash': 'FOOD00318',
#  'cardoon': 'FOOD00319',
#  'natal plum': 'FOOD00320',
#  'carob': 'FOOD00321',
#  'common carp': 'FOOD00322',
#  'cassava': 'FOOD00323',
#  'channel catfish': 'FOOD00324',
#  'chayote': 'FOOD00325',
#  'cherimoya': 'FOOD00326',
#  'chervil': 'FOOD00327',
#  'chia': 'FOOD00328',
#  'chicken': 'FOOD00329',
#  'chinese broccoli': 'FOOD00330',
#  'chinese chestnut': 'FOOD00331',
#  'chinese water chestnut': 'FOOD00332',
#  'garland chrysanthemum': 'FOOD00333',
#  'cisco': 'FOOD00334',
#  'nuttall cockle': 'FOOD00335',
#  'coconut': 'FOOD00336',
#  'pacific cod': 'FOOD00337',
#  'atlantic cod': 'FOOD00338',
#  'common octopus': 'FOOD00339',
#  'corn salad': 'FOOD00340',
#  'cottonseed': 'FOOD00341',
#  'catjang pea': 'FOOD00342',
#  'malus (crab apple)': 'FOOD00343',
#  'squashberry': 'FOOD00344',
#  'atlantic croaker': 'FOOD00345',
#  'cusk': 'FOOD00346',
#  'cuttlefish': 'FOOD00347',
#  'mule deer': 'FOOD00348',
#  'devilfish': 'FOOD00349',
#  'dock': 'FOOD00350',
#  'dolphin fish': 'FOOD00351',
#  'freshwater drum': 'FOOD00352',
#  'mallard duck': 'FOOD00353',
#  'dungeness crab': 'FOOD00354',
#  'durian': 'FOOD00355',
#  'eastern oyster': 'FOOD00356',
#  'freshwater eel': 'FOOD00357',
#  'elderberry': 'FOOD00358',
#  'elk': 'FOOD00359',
#  'emu': 'FOOD00360',
#  'oregon yampah': 'FOOD00361',
#  'european anchovy': 'FOOD00362',
#  'european chestnut': 'FOOD00363',
#  'turbot': 'FOOD00364',
#  'fireweed': 'FOOD00365',
#  'florida pompano': 'FOOD00366',
#  'ginkgo nuts': 'FOOD00367',
#  'greylag goose': 'FOOD00368',
#  'grape': 'FOOD00369',
#  'greenland halibut/turbot': 'FOOD00370',
#  'groundcherry': 'FOOD00371',
#  'grouper': 'FOOD00372',
#  'guinea hen': 'FOOD00373',
#  'haddock': 'FOOD00374',
#  'hippoglossus (common halibut)': 'FOOD00375',
#  'hazelnut': 'FOOD00376',
#  'hickory nut': 'FOOD00377',
#  'horse': 'FOOD00378',
#  'horseradish tree': 'FOOD00379',
#  'alaska blueberry': 'FOOD00380',
#  'hyacinth bean': 'FOOD00381',
#  'irish moss': 'FOOD00382',
#  'pacific jack mackerel': 'FOOD00383',
#  'jackfruit': 'FOOD00384',
#  'japanese chestnut': 'FOOD00385',
#  'java plum': 'FOOD00386',
#  'jerusalem artichoke': 'FOOD00387',
#  'jujube': 'FOOD00388',
#  'jute': 'FOOD00389',
#  'kale': 'FOOD00390',
#  'kelp': 'FOOD00391',
#  'king mackerel': 'FOOD00392',
#  'kumquat': 'FOOD00393',
#  'lambsquarters': 'FOOD00394',
#  'leather chiton': 'FOOD00395',
#  'wild leek': 'FOOD00396',
#  'common ling': 'FOOD00397',
#  'lingcod': 'FOOD00398',
#  'american lobster': 'FOOD00399',
#  'loganberry': 'FOOD00400',
#  'lotus': 'FOOD00401',
#  'sacred lotus': 'FOOD00402',
#  'white lupine': 'FOOD00403',
#  'malabar spinach': 'FOOD00404',
#  'mammee apple': 'FOOD00405',
#  'purple mangosteen': 'FOOD00406',
#  'alpine sweetvetch': 'FOOD00407',
#  'milkfish': 'FOOD00408',
#  'monkfish': 'FOOD00409',
#  'moth bean': 'FOOD00410',
#  'mountain yam': 'FOOD00411',
#  'striped mullet': 'FOOD00412',
#  'white mustard': 'FOOD00413',
#  'mustard spinach': 'FOOD00414',
#  'new zealand spinach': 'FOOD00415',
#  'nopal': 'FOOD00416',
#  'ocean pout': 'FOOD00417',
#  'north pacific giant octopus': 'FOOD00418',
#  'ohelo berry': 'FOOD00419',
#  'okra': 'FOOD00420',
#  'tunicate': 'FOOD00421',
#  'ostrich': 'FOOD00422',
#  'spotted seal': 'FOOD00423',
#  'pacific herring': 'FOOD00424',
#  'pacific oyster': 'FOOD00425',
#  'pacific rockfish': 'FOOD00426',
#  'velvet duck': 'FOOD00427',
#  'pepper (c. frutescens)': 'FOOD00428',
#  'common persimmon': 'FOOD00429',
#  'pheasant': 'FOOD00430',
#  'northern pike': 'FOOD00431',
#  'pili nut': 'FOOD00432',
#  'colorado pinyon': 'FOOD00433',
#  'pitanga': 'FOOD00434',
#  'plains prickly pear': 'FOOD00435',
#  'french plantain': 'FOOD00436',
#  'american pokeweed': 'FOOD00437',
#  'opium poppy': 'FOOD00438',
#  'prairie turnip': 'FOOD00439',
#  'prickly pear': 'FOOD00440',
#  'quinoa': 'FOOD00441',
#  'european rabbit': 'FOOD00442',
#  'rainbow smelt': 'FOOD00443',
#  'rainbow trout': 'FOOD00444',
#  'malabar plum': 'FOOD00445',
#  'rose hip': 'FOOD00446',
#  'roselle': 'FOOD00447',
#  'orange roughy': 'FOOD00448',
#  'sablefish': 'FOOD00449',
#  'pink salmon': 'FOOD00450',
#  'chum salmon': 'FOOD00451',
#  'coho salmon': 'FOOD00452',
#  'sockeye salmon': 'FOOD00453',
#  'chinook salmon': 'FOOD00454',
#  'atlantic salmon': 'FOOD00455',
#  'salmonberry': 'FOOD00456',
#  'common salsify': 'FOOD00457',
#  'sapodilla': 'FOOD00458',
#  'mamey sapote': 'FOOD00459',
#  'spanish mackerel': 'FOOD00460',
#  'pacific sardine': 'FOOD00461',
#  'scallop': 'FOOD00462',
#  'scup': 'FOOD00463',
#  'sea cucumber': 'FOOD00464',
#  'steller sea lion': 'FOOD00465',
#  'bearded seal': 'FOOD00466',
#  'ringed seal': 'FOOD00467',
#  'sea trout': 'FOOD00468',
#  'sesbania flower': 'FOOD00469',
#  'american shad': 'FOOD00470',
#  'shark': 'FOOD00471',
#  'sheefish': 'FOOD00472',
#  'sheep (mutton, lamb)': 'FOOD00473',
#  'sheepshead': 'FOOD00474',
#  'hedge mustard': 'FOOD00475',
#  'skipjack tuna': 'FOOD00476',
#  'snapper': 'FOOD00477',
#  'soursop': 'FOOD00478',
#  'spelt': 'FOOD00479',
#  'spirulina': 'FOOD00480',
#  'squab': 'FOOD00481',
#  'strawberry guava': 'FOOD00482',
#  'greater sturgeon': 'FOOD00483',
#  'white sucker': 'FOOD00484',
#  'sugar apple': 'FOOD00485',
#  'pumpkinseed sunfish': 'FOOD00486',
#  'swordfish': 'FOOD00487',
#  'taro': 'FOOD00488',
#  'teff': 'FOOD00489',
#  'tilefish': 'FOOD00490',
#  'mexican groundcherry': 'FOOD00491',
#  'towel gourd': 'FOOD00492',
#  'salmonidae (salmon, trout)': 'FOOD00493',
#  'turkey': 'FOOD00494',
#  'cattle (beef, veal)': 'FOOD00495',
#  'walleye': 'FOOD00496',
#  'alaska pollock': 'FOOD00497',
#  'wasabi': 'FOOD00498',
#  'wax gourd': 'FOOD00499',
#  'whelk': 'FOOD00500',
#  'coalfish pollock': 'FOOD00501',
#  'broad whitefish': 'FOOD00502',
#  'whitefish': 'FOOD00503',
#  'whiting': 'FOOD00504',
#  'wild rice': 'FOOD00505',
#  'tea leaf willow': 'FOOD00506',
#  'winged bean': 'FOOD00507',
#  'yam': 'FOOD00508',
#  'jicama': 'FOOD00509',
#  'yautia': 'FOOD00510',
#  'yellowfin tuna': 'FOOD00511',
#  'yellowtail amberjack': 'FOOD00512',
#  'pollock': 'FOOD00513',
#  'albacore tuna': 'FOOD00514',
#  'gadus (common cod)': 'FOOD00515',
#  'atlantic halibut': 'FOOD00516',
#  'pacific halibut': 'FOOD00517',
#  'pacific salmon': 'FOOD00518',
#  'smelt': 'FOOD00519',
#  'clupeinae (herring, sardine, sprat)': 'FOOD00520',
#  'spiny lobster': 'FOOD00521',
#  'snow crab': 'FOOD00522',
#  'black-eyed pea': 'FOOD00523',
#  'deer': 'FOOD00524',
#  'macadamia nut': 'FOOD00525',
#  'percoidei (bass and others)': 'FOOD00526',
#  'perciformes': 'FOOD00527',
#  'rabbit': 'FOOD00528',
#  'domestic goat': 'FOOD00529',
#  'beefalo': 'FOOD00530',
#  'bivalvia (clam, mussel, oyster)': 'FOOD00531',
#  'squid': 'FOOD00532',
#  'shrimp': 'FOOD00533',
#  'crayfish': 'FOOD00534',
#  'flatfish': 'FOOD00535',
#  'domestic pig': 'FOOD00536',
#  'walrus': 'FOOD00537',
#  'alaska wild rhubarb': 'FOOD00538',
#  'oriental wheat': 'FOOD00539',
#  'yardlong bean': 'FOOD00540',
#  'quail': 'FOOD00541',
#  'boysenberry': 'FOOD00542',
#  'persian lime': 'FOOD00543',
#  'feijoa': 'FOOD00544',
#  'rowal': 'FOOD00545',
#  "jew's ear": 'FOOD00546',
#  'common mushroom': 'FOOD00547',
#  'shiitake': 'FOOD00548',
#  'purple laver': 'FOOD00549',
#  'wakame': 'FOOD00550',
#  'enokitake': 'FOOD00551',
#  'epazote': 'FOOD00552',
#  'oyster mushroom': 'FOOD00553',
#  'cloud ear fungus': 'FOOD00554',
#  'maitake': 'FOOD00555',
#  'ostrich fern': 'FOOD00556',
#  'spot croaker': 'FOOD00557',
#  'sourdock': 'FOOD00558',
#  'tinda': 'FOOD00559',
#  'atlantic menhaden': 'FOOD00560',
#  'wheat': 'FOOD00561',
#  'common chokecherry': 'FOOD00562',
#  'agave': 'FOOD00563',
#  'narrowleaf cattail': 'FOOD00564',
#  'jellyfish': 'FOOD00565',
#  'anchovy': 'FOOD00566',
#  'blue whiting': 'FOOD00567',
#  'carp bream': 'FOOD00568',
#  'chanterelle': 'FOOD00569',
#  'sturgeon': 'FOOD00570',
#  'charr': 'FOOD00571',
#  'cinnamon': 'FOOD00572',
#  'crab': 'FOOD00573',
#  'common dab': 'FOOD00574',
#  'spiny dogfish': 'FOOD00575',
#  'anatidae': 'FOOD00576',
#  'anguilliformes': 'FOOD00577',
#  'true frog': 'FOOD00578',
#  'garfish': 'FOOD00579',
#  'gadiformes': 'FOOD00580',
#  'mountain hare': 'FOOD00581',
#  'lake trout': 'FOOD00582',
#  'lemon sole': 'FOOD00583',
#  'clawed lobster': 'FOOD00584',
#  'lumpsucker': 'FOOD00585',
#  'scombridae (bonito, mackerel, tuna)': 'FOOD00586',
#  'marine mussel': 'FOOD00587',
#  'norway haddock': 'FOOD00588',
#  'norway lobster': 'FOOD00589',
#  'norway pout': 'FOOD00590',
#  'oil palm': 'FOOD00591',
#  'true oyster': 'FOOD00592',
#  'sago palm': 'FOOD00593',
#  'persimmon': 'FOOD00594',
#  'pikeperch': 'FOOD00595',
#  'pleuronectidae (dab, halibut, plaice)': 'FOOD00596',
#  'rock ptarmigan': 'FOOD00597',
#  'pacific ocean perch': 'FOOD00598',
#  'black salsify': 'FOOD00599',
#  'true seal': 'FOOD00600',
#  'red algae': 'FOOD00601',
#  'kombu': 'FOOD00602',
#  'snail': 'FOOD00603',
#  'true sole': 'FOOD00604',
#  'catfish': 'FOOD00605',
#  'thistle': 'FOOD00606',
#  'thunnus': 'FOOD00607',
#  'walnut': 'FOOD00608',
#  'cetacea (dolphin, porpoise, whale)': 'FOOD00609',
#  'columbidae (dove, pigeon)': 'FOOD00610',
#  'conch': 'FOOD00611',
#  'grape wine': 'FOOD00612',
#  'berry wine': 'FOOD00613',
#  'other wine': 'FOOD00614',
#  'apple cider': 'FOOD00615',
#  'liquor': 'FOOD00616',
#  'cheese': 'FOOD00617',
#  'milk (cow)': 'FOOD00618',
#  'eggs': 'FOOD00619',
#  'yogurt': 'FOOD00620',
#  'bean': 'FOOD00621',
#  'vodka': 'FOOD00622',
#  'whisky': 'FOOD00623',
#  'ice cream': 'FOOD00624',
#  'gin': 'FOOD00625',
#  'honey': 'FOOD00626',
#  'liquorice': 'FOOD00627',
#  'vinegar': 'FOOD00628',
#  'rum': 'FOOD00629',
#  'port wine': 'FOOD00630',
#  'vermouth': 'FOOD00631',
#  'sherry': 'FOOD00632',
#  'madeira wine': 'FOOD00633',
#  'nougat': 'FOOD00634',
#  'toffee': 'FOOD00635',
#  'cake': 'FOOD00636',
#  'pizza': 'FOOD00637',
#  'ymer': 'FOOD00638',
#  'other snack food': 'FOOD00639',
#  'crisp bread': 'FOOD00640',
#  'pastry': 'FOOD00641',
#  'dragée': 'FOOD00642',
#  'chewing gum': 'FOOD00643',
#  'marzipan': 'FOOD00644',
#  'salad dressing': 'FOOD00645',
#  'sauce': 'FOOD00646',
#  'salt': 'FOOD00647',
#  'butter': 'FOOD00648',
#  'butter substitute': 'FOOD00649',
#  'cream': 'FOOD00650',
#  'sugar': 'FOOD00651',
#  'sausage': 'FOOD00652',
#  'meatball': 'FOOD00653',
#  'mustard': 'FOOD00654',
#  'pate': 'FOOD00655',
#  'sugar substitute': 'FOOD00656',
#  'meat bouillon': 'FOOD00657',
#  'whey': 'FOOD00658',
#  'casein': 'FOOD00659',
#  'fruit preserve': 'FOOD00660',
#  'leavening agent': 'FOOD00661',
#  'marshmallow': 'FOOD00662',
#  'gelatin': 'FOOD00663',
#  'water': 'FOOD00664',
#  'other fish product': 'FOOD00665',
#  'milk (human)': 'FOOD00666',
#  'other beverage': 'FOOD00667',
#  'baby food': 'FOOD00668',
#  'dumpling': 'FOOD00669',
#  'soup': 'FOOD00670',
#  'other vegetable product': 'FOOD00671',
#  'unclassified food or beverage': 'FOOD00672',
#  'syrup': 'FOOD00673',
#  'tallow': 'FOOD00674',
#  'remoulade': 'FOOD00675',
#  'chocolate spread': 'FOOD00676',
#  'fruit gum': 'FOOD00677',
#  'curry powder': 'FOOD00678',
#  'other candy': 'FOOD00679',
#  'meringue': 'FOOD00680',
#  'lard': 'FOOD00681',
#  'other animal fat': 'FOOD00682',
#  'other cocoa product': 'FOOD00683',
#  'cocoa butter': 'FOOD00684',
#  'cocoa powder': 'FOOD00685',
#  'cocoa liquor': 'FOOD00686',
#  'chocolate': 'FOOD00687',
#  'hot chocolate': 'FOOD00688',
#  'dried milk': 'FOOD00689',
#  'milk (other mammals)': 'FOOD00690',
#  'kefir': 'FOOD00691',
#  'buttermilk': 'FOOD00692',
#  'other fermented milk': 'FOOD00693',
#  'soy sauce': 'FOOD00694',
#  'miso': 'FOOD00695',
#  'tofu': 'FOOD00696',
#  'zwieback': 'FOOD00697',
#  'roe': 'FOOD00698',
#  'cichlidae (tilapia)': 'FOOD00699',
#  'icing': 'FOOD00700',
#  'snack bar': 'FOOD00701',
#  'green turtle': 'FOOD00702',
#  'energy drink': 'FOOD00703',
#  'burrito': 'FOOD00704',
#  'hamburger': 'FOOD00705',
#  'baked beans': 'FOOD00706',
#  'chili': 'FOOD00707',
#  'taco': 'FOOD00708',
#  'tortilla': 'FOOD00709',
#  'nachos': 'FOOD00710',
#  'processed cheese': 'FOOD00711',
#  'salad': 'FOOD00712',
#  'cream substitute': 'FOOD00713',
#  'dulce de leche': 'FOOD00714',
#  'topping': 'FOOD00715',
#  'sweet custard': 'FOOD00716',
#  'egg roll': 'FOOD00717',
#  'heart of palm': 'FOOD00718',
#  'popcorn': 'FOOD00719',
#  'potato chip': 'FOOD00720',
#  'tortilla chip': 'FOOD00721',
#  'corn chip': 'FOOD00722',
#  'hibiscus tea': 'FOOD00723',
#  'stew': 'FOOD00724',
#  'gelatin dessert': 'FOOD00725',
#  'junket': 'FOOD00726',
#  'falafel': 'FOOD00727',
#  'frybread': 'FOOD00728',
#  'other frozen dessert': 'FOOD00729',
#  'lasagna': 'FOOD00730',
#  'morchella (morel)': 'FOOD00731',
#  'pancake': 'FOOD00732',
#  'pectin': 'FOOD00733',
#  'pudding': 'FOOD00734',
#  'waffle': 'FOOD00735',
#  'soy milk': 'FOOD00736',
#  'meatloaf': 'FOOD00737',
#  'sake': 'FOOD00738',
#  'cocktail': 'FOOD00739',
#  'couscous': 'FOOD00740',
#  'bulgur': 'FOOD00741',
#  'coffee substitute': 'FOOD00742',
#  'coffee mocha': 'FOOD00743',
#  'chimichanga': 'FOOD00744',
#  'semolina': 'FOOD00745',
#  'tapioca pearl': 'FOOD00746',
#  'tostada': 'FOOD00747',
#  'quesadilla': 'FOOD00748',
#  'baked potato': 'FOOD00749',
#  'hot dog': 'FOOD00750',
#  'spread': 'FOOD00751',
#  'enchilada': 'FOOD00752',
#  'egg substitute': 'FOOD00753',
#  'nutritional drink': 'FOOD00754',
#  'other sandwich': 'FOOD00755',
#  'ketchup': 'FOOD00756',
#  'breakfast sandwich': 'FOOD00757',
#  'adobo': 'FOOD00758',
#  'macaroni and cheese': 'FOOD00759',
#  'butterfat': 'FOOD00760',
#  'horned melon': 'FOOD00761',
#  'hushpuppy': 'FOOD00762',
#  'fruit juice': 'FOOD00763',
#  'relish': 'FOOD00764',
#  'other fruit product': 'FOOD00765',
#  'fruit salad': 'FOOD00766',
#  'soy yogurt': 'FOOD00767',
#  'vegetarian food': 'FOOD00768',
#  'veggie burger': 'FOOD00769',
#  'cold cut': 'FOOD00770',
#  'mixed nuts': 'FOOD00771',
#  'canola': 'FOOD00772',
#  'babassu palm': 'FOOD00773',
#  'cupuaçu': 'FOOD00774',
#  'shea tree': 'FOOD00775',
#  'oil-seed camellia': 'FOOD00776',
#  'ucuhuba': 'FOOD00777',
#  'phyllo dough': 'FOOD00778',
#  'cooking oil': 'FOOD00779',
#  'pie crust': 'FOOD00780',
#  'pie filling': 'FOOD00781',
#  'pie': 'FOOD00782',
#  'shortening': 'FOOD00783',
#  'soy cream': 'FOOD00784',
#  'ice cream cone': 'FOOD00785',
#  'molasses': 'FOOD00786',
#  'cracker': 'FOOD00787',
#  'nance': 'FOOD00788',
#  'naranjilla': 'FOOD00789',
#  'natto': 'FOOD00790',
#  'ravioli': 'FOOD00791',
#  'scrapple': 'FOOD00792',
#  'other pasta dish': 'FOOD00793',
#  'succotash': 'FOOD00794',
#  'tamale': 'FOOD00795',
#  'rice cake': 'FOOD00796',
#  'tree fern': 'FOOD00797',
#  'evaporated milk': 'FOOD00798',
#  'flour': 'FOOD00799',
#  'akutaq': 'FOOD00800',
#  'dough': 'FOOD00801',
#  'pita bread': 'FOOD00802',
#  'focaccia': 'FOOD00803',
#  'bagel': 'FOOD00804',
#  'other bread product': 'FOOD00805',
#  'piki bread': 'FOOD00806',
#  'french toast': 'FOOD00807',
#  'wheat bread': 'FOOD00808',
#  'rye bread': 'FOOD00809',
#  'oat bread': 'FOOD00810',
#  'potato bread': 'FOOD00811',
#  'cornbread': 'FOOD00812',
#  'corn grits': 'FOOD00813',
#  'multigrain bread': 'FOOD00814',
#  'rice bread': 'FOOD00815',
#  'pan dulce': 'FOOD00816',
#  'raisin bread': 'FOOD00817',
#  'wonton wrapper': 'FOOD00818',
#  'trail mix': 'FOOD00819',
#  'greenthread tea': 'FOOD00820',
#  'fruit-flavor drink': 'FOOD00821',
#  'vegetable juice': 'FOOD00822',
#  'horchata': 'FOOD00823',
#  'soft drink': 'FOOD00824',
#  'frozen yogurt': 'FOOD00825',
#  'milkshake': 'FOOD00826',
#  'chocolate mousse': 'FOOD00827',
#  'dripping': 'FOOD00828',
#  'pupusa': 'FOOD00829',
#  'empanada': 'FOOD00830',
#  'arepa': 'FOOD00831',
#  'ascidians': 'FOOD00832',
#  'gefilte fish': 'FOOD00833',
#  'yellow pond-lily': 'FOOD00834',
#  'fish burger': 'FOOD00835',
#  'other dish': 'FOOD00836',
#  'pot pie': 'FOOD00837',
#  'stuffing': 'FOOD00838',
#  'edible shell': 'FOOD00839',
#  'fudge': 'FOOD00840',
#  'candy bar': 'FOOD00841',
#  'condensed milk': 'FOOD00842',
#  'margarine': 'FOOD00843',
#  'margarine-like spread': 'FOOD00844',
#  'hummus': 'FOOD00845',
#  'potato puffs': 'FOOD00846',
#  'potato gratin': 'FOOD00847',
#  'milk substitute': 'FOOD00848',
#  'pepper (c. pubescens)': 'FOOD00849',
#  'soft-necked garlic': 'FOOD00850',
#  'cabbage': 'FOOD00851',
#  'chinese bayberry': 'FOOD00852',
#  'mushrooms': 'FOOD00853',
#  'alcoholic beverages': 'FOOD00854',
#  'onion-family vegetables': 'FOOD00855',
#  'pomes': 'FOOD00856',
#  'brassicas': 'FOOD00857',
#  'cereals and cereal products': 'FOOD00858',
#  'citrus': 'FOOD00859',
#  'cocoa and cocoa products': 'FOOD00860',
#  'coffee and coffee products': 'FOOD00861',
#  'crustaceans': 'FOOD00862',
#  'milk and milk products': 'FOOD00863',
#  'fats and oils': 'FOOD00864',
#  'fishes': 'FOOD00865',
#  'herbs and spices': 'FOOD00866',
#  'pulses': 'FOOD00867',
#  'mollusks': 'FOOD00868',
#  'nuts': 'FOOD00869',
#  'beverages': 'FOOD00870',
#  'fruits': 'FOOD00871',
#  'green vegetables': 'FOOD00872',
#  'root vegetables': 'FOOD00873',
#  'sunburst squash (pattypan squash)': 'FOOD00874',
#  'green zucchini': 'FOOD00875',
#  'yellow zucchini': 'FOOD00876',
#  'green bell pepper': 'FOOD00877',
#  'yellow bell pepper': 'FOOD00878',
#  'orange bell pepper': 'FOOD00879',
#  'red bell pepper': 'FOOD00880',
#  'italian sweet red pepper': 'FOOD00881',
#  'yellow wax bean': 'FOOD00882',
#  'green bean': 'FOOD00883',
#  'saskatoon berry': 'FOOD00884',
#  'nanking cherry': 'FOOD00885',
#  'japanese pumpkin': 'FOOD00886',
#  'white cabbage': 'FOOD00887',
#  'romaine lettuce': 'FOOD00888',
#  'cow milk, pasteurized, vitamin a + d added, 0% fat': 'FOOD00889',
#  'cow milk, pasteurized, vitamin a + d added, 1% fat': 'FOOD00890',
#  'cow milk, pasteurized, vitamin a + d added, 2% fat': 'FOOD00891',
#  'cow milk, pasteurized, vitamin d added, 3.25% fat': 'FOOD00892',
#  'castanospermum australe': 'FOOD00893',
#  'gentiana lutea': 'FOOD00894',
#  'juniperus communis': 'FOOD00895',
#  'albizia gummifera': 'FOOD00896',
#  'mundu': 'FOOD00897',
#  'rabbiteye blueberry': 'FOOD00898',
#  'yali pear': 'FOOD00899',
#  'asparagus racemosus': 'FOOD00900',
#  'evergreen blackberry': 'FOOD00901',
#  'asparagus fern': 'FOOD00902',
#  'thornless blackberry': 'FOOD00903',
#  'tropical highland blackberry': 'FOOD00904',
#  'andean blackberry': 'FOOD00905',
#  'blackberry': 'FOOD00906',
#  'black tea': 'FOOD00907',
#  'green tea': 'FOOD00908',
#  'olive oil': 'FOOD00909',
#  'macroalgae': 'FOOD00910',
#  'red wine': 'FOOD00911',
#  'linseed oil': 'FOOD00912',
#  'rapeseed oil': 'FOOD00913',
#  'soybean oil': 'FOOD00914',
#  'guarana': 'FOOD00915',
#  'mate': 'FOOD00916',
#  'white wine': 'FOOD00917',
#  'sour orange': 'FOOD00918',
#  'egg yolk': 'FOOD00919',
#  'rosé wine': 'FOOD00920',
#  'white mulberry': 'FOOD00921',
#  'canola oil': 'FOOD00922',
#  'dessert wine': 'FOOD00923',
#  'red champagne': 'FOOD00924',
#  'red tea': 'FOOD00925',
#  'white champagne': 'FOOD00926',
#  'red grape juice': 'FOOD00927',
#  'white grape juice': 'FOOD00928',
#  'crosne': 'FOOD00929',
#  'red clover': 'FOOD00930',
#  'partridge berry': 'FOOD00931',
#  'mikan': 'FOOD00932',
#  'mozzarella cheese': 'FOOD00933',
#  'plain cream cheese': 'FOOD00934',
#  'cheddar cheese': 'FOOD00935',
#  'parmesan cheese': 'FOOD00936',
#  'almond milk': 'FOOD00937',
#  'coconut milk': 'FOOD00938',
#  'salted butter': 'FOOD00939',
#  'sunflower oil': 'FOOD00940',
#  'coconut oil': 'FOOD00941',
#  'peanut oil': 'FOOD00942',
#  'cottonseed oil': 'FOOD00943',
#  'corn oil': 'FOOD00944',
#  'avocado oil': 'FOOD00945',
#  'grapeseed oil': 'FOOD00946',
#  'sesame oil': 'FOOD00947',
#  'monterey jack cheese': 'FOOD00948',
#  'swiss cheese': 'FOOD00949',
#  'cottage cheese': 'FOOD00950',
#  'blue cheese': 'FOOD00951',
#  'clam': 'FOOD00952',
#  'sour cream': 'FOOD00953',
#  'whole wheat bread': 'FOOD00954',
#  'jalapeno pepper': 'FOOD00955',
#  'greek feta cheese': 'FOOD00956',
#  'eddoe': 'FOOD00957',
#  'plantain': 'FOOD00958',
#  'clementine': 'FOOD00959',
#  'green apple': 'FOOD00960',
#  'white onion': 'FOOD00961',
#  'red onion': 'FOOD00962',
#  'green onion': 'FOOD00963',
#  'green grape': 'FOOD00964',
#  'red grape': 'FOOD00965',
#  'black plum': 'FOOD00966',
#  'green cabbage': 'FOOD00967',
#  'black raisin': 'FOOD00968',
#  'cannellini bean': 'FOOD00969',
#  'green lentil': 'FOOD00970',
#  'cubanelle pepper': 'FOOD00971',
#  'acorn squash': 'FOOD00972',
#  'iceberg lettuce': 'FOOD00973',
#  'japanese sea bass': 'FOOD00974',
#  'pea shoots': 'FOOD00975',
#  'yau choy': 'FOOD00976',
#  'water spinach': 'FOOD00977',
#  'chineese plum': 'FOOD00978',
#  'green plum': 'FOOD00979',
#  'wampee': 'FOOD00980',
#  'pitaya': 'FOOD00981',
#  'goji': 'FOOD00982',
#  'monk fruit': 'FOOD00983',
#  'cantaloupe melon': 'FOOD00984',
#  'hawthorn': 'FOOD00985',
#  'lantern fruit': 'FOOD00986',
#  'white bread': 'FOOD00987',
#  'cape gooseberry': 'FOOD00988',
#  'herbal tea': 'FOOD00989',
#  'fish oil': 'FOOD00990',
#  'taco shell': 'FOOD00991',
#  'tostada shell': 'FOOD00992'}

# %%
# caffein -> compounds
# pottasiun -> compounds
# folic acid -> compounds
# antacids -> compounds Ketoconazole
# histamine-containing foods -> compounds Histamine
# xanthines -> compounds xanthine
# iodine -> compounds
# iron supplements -> iron

compounds = pd.read_csv(triplets_dir + 'compounds_names.tsv', sep='\t', index_col=[0])
compound_ids = compounds.compound_id
compound_names = compounds.name.str.lower()
compound_id_map_dict = dict(zip(compound_names, compound_ids))
compound_id_map_dict
# Out:
# {'d-galactose': 'FDB012703',
#  'syringic acid': 'FDB000514',
#  'acutissimin a': 'FDB018737',
#  'l-cysteine': 'FDB012678',
#  'silver': 'FDB004188',
#  'l-chicoric acid': 'FDB002580',
#  'selenium': 'FDB013400',
#  'lycopene': 'FDB014534',
#  'butein': 'FDB000082',
#  'kaempferol': 'FDB000633',
#  'lutein': 'FDB015471',
#  'linalool': 'FDB014940',
#  'pentoses': 'FDB005965',
#  'papaverine': 'FDB000447',
#  'ecdysone': 'FDB007162',
#  'phellandrene': 'FDB003865',
#  'zinc': 'FDB003729',
#  'estrone': 'FDB012798',
#  'capsaicin': 'FDB012411',
#  '2,6-dihydroxybenzoic acid': 'FDB000845',
#  'l-aspartic acid': 'FDB012567',
#  '4-methylphenol': 'FDB008789',
#  'vanillin': 'FDB000838',
#  'apigeninidin': 'FDB001565',
#  'l-methionine': 'FDB012683',
#  'ferulic acid': 'FDB012801',
#  'diosmetin': 'FDB000861',
#  'retinol': 'FDB013828',
#  'hydroquinone': 'FDB000885',
#  'lormetazepam': 'FDB007119',
#  'myricetin': 'FDB012724',
#  'glucosamine': 'FDB022668',
#  'cyanidin': 'FDB002602',
#  '(-)-matairesinol': 'FDB014417',
#  'sinigrin': 'FDB012319',
#  '5-isopropyl-2-methylphenol': 'FDB014512',
#  'sucrose': 'FDB001131',
#  '(±)-tryptophan': 'FDB002251',
#  'myo-inositol': 'FDB010547',
#  'isoprene': 'FDB005121',
#  'l-lysine': 'FDB000474',
#  'glycerol': 'FDB000756',
#  'histamine': 'FDB012596',
#  '7,8-dihydrolycopene': 'FDB015887',
#  'theophylline': 'FDB000453',
#  '(±)-phenylalanine': 'FDB013245',
#  'taurine': 'FDB003191',
#  'allicin': 'FDB012190',
#  'di-2-propenyl disulfide, 9ci': 'FDB012196',
#  'chloroform': 'FDB000760',
#  'genistein': 'FDB011828',
#  'd-mannitol': 'FDB001982',
#  'petunidin': 'FDB002755',
#  'd-glucitol': 'FDB011676',
#  'camphene': 'FDB009065',
#  '(±)-valine': 'FDB012740',
#  'beta-glucan': 'FDB005762',
#  'piperine': 'FDB000449',
#  'pantothenic acid': 'FDB008322',
#  'estriol': 'FDB006781',
#  '3,5-dihydroxybenzoic acid': 'FDB000848',
#  'quercetin 3-rutinoside': 'FDB002536',
#  'diosmetin 7-rutinoside': 'FDB000693',
#  'apiforol': 'FDB017698',
#  'melatonin': 'FDB004234',
#  'd-xylose': 'FDB001136',
#  'cinnamic acid': 'FDB012052',
#  'l-dopa': 'FDB000567',
#  'bentonite': 'FDB012878',
#  'guanidine': 'FDB005416',
#  'longifolene': 'FDB005805',
#  '2-methoxyphenol': 'FDB011885',
#  '(-)-menthol': 'FDB014499',
#  'glutamic acid': 'FDB012536',
#  'cernuine': 'FDB012432',
#  'flavones': 'FDB006784',
#  'pinene': 'FDB004843',
#  'cobalt': 'FDB003581',
#  'benzoic acid': 'FDB008739',
#  'castalagin': 'FDB018931',
#  'glutathione': 'FDB001498',
#  '1-isopropyl-4-methylbenzene': 'FDB017358',
#  'l-glutamic acid': 'FDB012535',
#  'punicalin': 'FDB018735',
#  'citronellol': 'FDB014490',
#  'pyridoxine': 'FDB000574',
#  'l-asparagine': 'FDB000787',
#  'beta-d-glucopyranose': 'FDB011824',
#  'cafestol': 'FDB014432',
#  'beta-sitosterol': 'FDB012362',
#  'ascorbic acid': 'FDB001223',
#  'l-tryptophan': 'FDB002250',
#  'd-ornithine': 'FDB023157',
#  'ursolic acid': 'FDB014373',
#  'alliin': 'FDB000558',
#  'ethanol': 'FDB000753',
#  'riboflavine': 'FDB012160',
#  'apigenin': 'FDB002798',
#  'formaldehyde': 'FDB009445',
#  'coumestrol': 'FDB011663',
#  'potassium': 'FDB003521',
#  '1h-indole-3-methanol': 'FDB000939',
#  'adenosine': 'FDB003554',
#  'phenol': 'FDB000893',
#  'secoisolariciresinol': 'FDB012660',
#  'cholesterol': 'FDB013269',
#  'testosterone': 'FDB011544',
#  'theaflavin': 'FDB012511',
#  'nicotinic acid': 'FDB001014',
#  'geraniol': 'FDB013792',
#  'rubber, natural-smoked sheet and latex solids (hevea brasiliensis)': 'FDB010210',
#  'phytofluene': 'FDB013304',
#  'manganese': 'FDB003636',
#  "(3r,3'r, all-e)-zeaxanthin": 'FDB019865',
#  'phytomenadione': 'FDB012357',
#  'urea': 'FDB012174',
#  'betulinic acid': 'FDB001532',
#  'methylparaben': 'FDB010509',
#  'ascaridole': 'FDB014503',
#  'alpha-cedrene': 'FDB003904',
#  'carnosol': 'FDB014814',
#  'pterostilbene': 'FDB012375',
#  'indole': 'FDB012008',
#  'succinic acid': 'FDB001931',
#  'isoeugenol': 'FDB002728',
#  'choline': 'FDB000710',
#  'vanadium': 'FDB003792',
#  'peonidin': 'FDB002753',
#  'betanin': 'FDB000497',
#  'gluconasturtiin': 'FDB017781',
#  '2,4-dihydroxybenzoic acid': 'FDB000842',
#  'glucoraphanin': 'FDB017756',
#  'inulin': 'FDB001141',
#  'aesculin': 'FDB002776',
#  'hydroxytyrosol': 'FDB008754',
#  'ellagic acid': 'FDB012575',
#  'campesterol': 'FDB012521',
#  'lanosterol': 'FDB013802',
#  'curcumin': 'FDB012292',
#  'gallic acid': 'FDB000662',
#  'oleanolic acid': 'FDB013034',
#  'creatine': 'FDB005403',
#  'beta-carotene': 'FDB014613',
#  'phloretin': 'FDB015553',
#  'hesperidin': 'FDB002680',
#  'nicotine': 'FDB003968',
#  'aromadendrin': 'FDB002806',
#  '(2e,7r,11r)-2-phyten-1-ol': 'FDB014472',
#  'oleic acid': 'FDB012858',
#  'alpha-lactose': 'FDB021789',
#  'methyl salicylate': 'FDB012459',
#  '(s)-naringenin': 'FDB000678',
#  'arbutin': 'FDB001221',
#  'pectic acid': 'FDB021453',
#  'allantoin': 'FDB001613',
#  'acacetin': 'FDB002766',
#  'stigmasterol': 'FDB001936',
#  'isorhamnetin': 'FDB000604',
#  'alpha-d-glucopyranose': 'FDB011829',
#  'dopamine': 'FDB012163',
#  'nitrogen': 'FDB013398',
#  '2,3-dihydroxybenzoic acid': 'FDB012200',
#  'polysaccharides': 'FDB003659',
#  'biotin': 'FDB014510',
#  'd-camphor': 'FDB009067',
#  'delphinidin': 'FDB002613',
#  '1,3-benzenediol': 'FDB008738',
#  '7-methyl-3-methylene-1,6-octadiene': 'FDB017400',
#  'l-tyrosine': 'FDB000446',
#  'dillapiol': 'FDB002649',
#  '(-)-alpha-narcotine': 'FDB011477',
#  'cyanocobalamin': 'FDB013264',
#  'nicotinamide': 'FDB012485',
#  'phosphorus': 'FDB003520',
#  'phytoene': 'FDB015831',
#  'stigmastanol': 'FDB001305',
#  'cadinol': 'FDB006082',
#  '4-hydroxybenzoic acid': 'FDB010508',
#  'ergosterol': 'FDB012612',
#  'gibberellins': 'FDB005727',
#  'progesterone': 'FDB001871',
#  'atropine': 'FDB004090',
#  'delta-carotene': 'FDB015894',
#  'l-histidine': 'FDB011856',
#  'gentisic acid': 'FDB000844',
#  'glycitein': 'FDB000698',
#  'caffeic acid': 'FDB002558',
#  'cadinene': 'FDB009046',
#  'lactose': 'FDB001145',
#  'cycloartenol': 'FDB015503',
#  'l-threonine': 'FDB011999',
#  'apiole': 'FDB011929',
#  'codeine': 'FDB012162',
#  'catechin': 'FDB002571',
#  '(r)c(s)s-alliin': 'FDB011674',
#  'betulin': 'FDB015789',
#  'casuarictin': 'FDB018815',
#  'limonene': 'FDB013567',
#  'pyruvic acid': 'FDB008293',
#  'eugenol': 'FDB012171',
#  'rubixanthin': 'FDB014606',
#  'anethole': 'FDB002793',
#  'ornithine': 'FDB003654',
#  'epsilon-carotene': 'FDB004662',
#  'luteolin': 'FDB013255',
#  "3',4',5,7-tetrahydroxyflavanone": 'FDB011936',
#  'hydroxyacetic acid': 'FDB003298',
#  'grandinin': 'FDB018941',
#  'betaine': 'FDB009020',
#  'parthenolide': 'FDB005891',
#  'saponins': 'FDB003695',
#  'glucotropaeolin': 'FDB017777',
#  'oleuropein': 'FDB014653',
#  'rubidium': 'FDB003783',
#  '(+)-pinoresinol': 'FDB002760',
#  'punicalagin': 'FDB016425',
#  'trans-caffeic acid': 'FDB002559',
#  'caffeine': 'FDB002100',
#  'pelargonidin': 'FDB012426',
#  'fisetin': 'FDB000624',
#  '3-hydroxybenzoic acid': 'FDB010507',
#  'quercetin': 'FDB011904',
#  'diazepam': 'FDB007103',
#  'piceatannol': 'FDB012295',
#  'dodecanoic acid': 'FDB003010',
#  '(±)-cystine': 'FDB012672',
#  '(-)-quinic acid': 'FDB001170',
#  'd-fructose': 'FDB012528',
#  'chromium': 'FDB003516',
#  'iodine': 'FDB003635',
#  'alpha-carotene': 'FDB013716',
#  '(±)-borneol': 'FDB013574',
#  'gamma-carotene': 'FDB014328',
#  'malvidin': 'FDB002713',
#  'hemin': 'FDB005746',
#  'vitamin d': 'FDB021586',
#  'l-cystine': 'FDB012563',
#  'daidzein': 'FDB002608',
#  'adenine': 'FDB012266',
#  '2-isopropyl-5-methylphenol': 'FDB014795',
#  'beta-cryptoxanthin': 'FDB012019',
#  '3-phenyl-2-propenal': 'FDB008781',
#  'theogallin': 'FDB018832',
#  '2-hydroxy-6-pentadecylbenzoic acid': 'FDB000869',
#  'citronellal': 'FDB014617',
#  'leucocyanidin': 'FDB017699',
#  'silicon': 'FDB003713',
#  'molybdenum': 'FDB003653',
#  'tangeritin': 'FDB002412',
#  'zeaxanthin': 'FDB014726',
#  'quercitrin': 'FDB011884',
#  'thiamine': 'FDB008424',
#  'glycine': 'FDB000484',
#  'copper': 'FDB003582',
#  'ammonia': 'FDB003908',
#  '4(10)-thujene': 'FDB013516',
#  'lignin': 'FDB009721',
#  'chrysin': 'FDB015535',
#  'iron': 'FDB016251'}

# %%
# substitue general groups of food with specific foods
new_rows = []

for i, row in dfi.iterrows():
    food_name = row['drug2']
    
    food_to_add = []
    
    if food_name == 'herbs and supplements with anticoagulant/antiplatelet activity':
        food_to_add = herbs
    elif food_name == 'histamine-containing foods':
        food_to_add = histamine_food
    elif food_name == 'tyramine-containing foods and supplements':
        food_to_add = tyramine_food
    else:
        new_rows.append(row)
    
    for f in food_to_add:
        new_rows.append((row['drug1'], row['interaction'], f))
    
new_dfi = pd.DataFrame(new_rows, columns=['drug1', 'interaction', 'drug2'])    
new_dfi
# Out:
#         drug1                       interaction            drug2
# 0     DB00001  increase_antiplatelet_activities             aloe
# 1     DB00001  increase_antiplatelet_activities        cranberry
# 2     DB00001  increase_antiplatelet_activities        chamomile
# 3     DB00001  increase_antiplatelet_activities         feverfew
# 4     DB00001  increase_antiplatelet_activities           garlic
# ...       ...                               ...              ...
# 2785  DB15982            increase_effectiveness             food
# 2786  DB16165            decrease_effectiveness       grapefruit
# 2787  DB16261            increase_effectiveness  a high fat meal
# 2788  DB16390            decrease_effectiveness  St. John's Wort
# 2789  DB16703            increase_effectiveness             food
#
# [2790 rows x 3 columns]

# %%
# substitute named with ids

dfi_with_ids = new_dfi
dfi_with_ids['changed'] = list(itertools.repeat(False, dfi_with_ids.shape[0]))

food_names2keep = ['alcohol', 'food', "St. John's Wort", 'hypertensive herbs', 'calcium', 'vitamin supplements']

for i, row in dfi_with_ids.iterrows():
    food_name = row['drug2']
    food_id = food_id_map_dict.get(food_name)

    if food_id is None:
        compound_id = compound_id_map_dict.get(food_name)
        if compound_id is not None:
            food_id = compound_id
            dfi_with_ids.at[i, 'changed'] = True
            dfi_with_ids.at[i, 'drug2'] = food_id
        
        if food_name in food_names2keep:
            food_id = food_name
            dfi_with_ids.at[i, 'changed'] = True

        if food_name == 'dairy product':
            food_id = food_id_map_dict.get('milk and milk products')
            dfi_with_ids.at[i, 'changed'] = True
            dfi_with_ids.at[i, 'drug2'] = food_id
            
        if food_name == 'natural licorice':
            food_id = food_id_map_dict.get('liquorice')
            dfi_with_ids.at[i, 'changed'] = True
            dfi_with_ids.at[i, 'drug2'] = food_id
            
        if food_name == 'meal':
            food_id = 'food'
            dfi_with_ids.at[i, 'changed'] = True  
            dfi_with_ids.at[i, 'drug2'] = food_id
            
        # TODO:
        # foods rich in vitamin k -> vitamin K -> keep
        # foods containing vitamin c -> vitamin C -> keep
    
    else:
        dfi_with_ids.at[i, 'changed'] = True
        dfi_with_ids.at[i, 'drug2'] = food_id

# %%
dfi_with_ids = dfi_with_ids.drop(dfi_with_ids[dfi_with_ids.changed == False].index).drop(columns='changed')

# %%
dfi_with_ids
# Out:
#         drug1                       interaction                drug2
# 62    DB00011            decrease_effectiveness              alcohol
# 105   DB00017          decrease_adverse_effects              calcium
# 106   DB00017          decrease_adverse_effects  vitamin supplements
# 112   DB00029  increase_antiplatelet_activities            FOOD00008
# 113   DB00029  increase_antiplatelet_activities            FOOD00206
# ...       ...                               ...                  ...
# 2784  DB15873            increase_effectiveness            FOOD00664
# 2785  DB15982            increase_effectiveness                 food
# 2786  DB16165            decrease_effectiveness            FOOD00256
# 2788  DB16390            decrease_effectiveness      St. John's Wort
# 2789  DB16703            increase_effectiveness                 food
#
# [1918 rows x 3 columns]

# %%
dfi_with_ids.to_csv(triplets_dir + 'dfi_processed.tsv', sep='\t')
